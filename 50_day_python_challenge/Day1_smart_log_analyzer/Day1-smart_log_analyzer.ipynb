# %%
# Read log file
with open ("server.log", "r") as f: #file object
    log = f.read() # return one single string in log 
    print(log)
# Out:
# 2025-01-01 09:00:01 INFO Application started
# 2025-01-01 09:00:05 INFO Loading configuration file
# 2025-01-01 09:00:07 WARNING Config value 'MAX_CONN' not set, using default
# 2025-01-01 09:00:10 INFO Connecting to database
# 2025-01-01 09:00:12 ERROR Database connection failed
# 2025-01-01 09:00:15 INFO Retrying database connection
# 2025-01-01 09:00:18 ERROR Database connection failed
# 2025-01-01 09:00:22 ERROR Database connection failed
# 2025-01-01 09:00:25 WARNING High memory usage detected
# 2025-01-01 09:00:30 INFO Memory usage normalized
# 2025-01-01 09:01:00 INFO User login successful: user_id=101
# 2025-01-01 09:01:10 INFO User login successful: user_id=102
# 2025-01-01 09:01:15 WARNING Disk usage above 75%
# 2025-01-01 09:01:20 INFO Scheduled job started: cleanup_task
# 2025-01-01 09:01:25 ERROR Failed to delete temp files
# 2025-01-01 09:01:30 INFO Scheduled job completed
# 2025-01-01 09:02:00 INFO API request received
# ...

# %%
log_msg ={}
level_count = {
    'INFO': 0,
    'ERROR': 0,
    'WARNING':0

}
with open ("server.log", "r") as f: 
    for line in f:
        log+= line
        split_log = line.split()
        level = split_log[2]
        level_count[level]+=1
        msg = " ".join(split_log[3:])
        log_msg = log_msg[msg] ##?????
    print(log)
    
    print(level_count)
    print(f"log_msg is {log_msg}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 15
#      13     level_count[level]+=1
#      14     msg = " ".join(split_log[3:])
# ---> 15     log_msg = log_msg[msg]
#      16 print(log)
#      18 print(level_count)
#
# KeyError: 'Application started'

# %%
# line count
line_count = len(log.split('\n'))
print(f"total line count:{line_count}")
# Out:
# total line count:28

# %%
# Split log 

split_log = log.split()
print(split_log)
# Out:
# ['2025-01-01', '09:00:01', 'INFO', 'Application', 'started', '2025-01-01', '09:00:05', 'INFO', 'Loading', 'configuration', 'file', '2025-01-01', '09:00:07', 'WARNING', 'Config', 'value', "'MAX_CONN'", 'not', 'set,', 'using', 'default', '2025-01-01', '09:00:10', 'INFO', 'Connecting', 'to', 'database', '2025-01-01', '09:00:12', 'ERROR', 'Database', 'connection', 'failed', '2025-01-01', '09:00:15', 'INFO', 'Retrying', 'database', 'connection', '2025-01-01', '09:00:18', 'ERROR', 'Database', 'connection', 'failed', '2025-01-01', '09:00:22', 'ERROR', 'Database', 'connection', 'failed', '2025-01-01', '09:00:25', 'WARNING', 'High', 'memory', 'usage', 'detected', '2025-01-01', '09:00:30', 'INFO', 'Memory', 'usage', 'normalized', '2025-01-01', '09:01:00', 'INFO', 'User', 'login', 'successful:', 'user_id=101', '2025-01-01', '09:01:10', 'INFO', 'User', 'login', 'successful:', 'user_id=102', '2025-01-01', '09:01:15', 'WARNING', 'Disk', 'usage', 'above', '75%', '2025-01-01', '09:01:20', 'INFO', 'S
# ...

# %%
level = split_log[2]
print(level)
# Out:
# INFO

# %%
with open('server.log', 'r') as f:
    log = f.read()
print(log)
# Out:
# 2025-01-01 09:00:01 INFO Application started
# 2025-01-01 09:00:05 INFO Loading configuration file
# 2025-01-01 09:00:07 WARNING Config value 'MAX_CONN' not set, using default
# 2025-01-01 09:00:10 INFO Connecting to database
# 2025-01-01 09:00:12 ERROR Database connection failed
# 2025-01-01 09:00:15 INFO Retrying database connection
# 2025-01-01 09:00:18 ERROR Database connection failed
# 2025-01-01 09:00:22 ERROR Database connection failed
# 2025-01-01 09:00:25 WARNING High memory usage detected
# 2025-01-01 09:00:30 INFO Memory usage normalized
# 2025-01-01 09:01:00 INFO User login successful: user_id=101
# 2025-01-01 09:01:10 INFO User login successful: user_id=102
# 2025-01-01 09:01:15 WARNING Disk usage above 75%
# 2025-01-01 09:01:20 INFO Scheduled job started: cleanup_task
# 2025-01-01 09:01:25 ERROR Failed to delete temp files
# 2025-01-01 09:01:30 INFO Scheduled job completed
# 2025-01-01 09:02:00 INFO API request received
# ...
